# %%
import pandas
import numpy
import matplotlib

# %%
words = pandas.read_csv("../WordsResearch/words.csv")

# %%
print(words)
# Out:
#              word  success_rate  offered  correct  wrong     id     rank  \
# 0           aback     22.222222        9        2      7  13512  20268.0
# 1         abandon     12.500000        8        1      7  11353   3837.0
# 2       abandoned     40.000000       15        6      9  13458   8493.0
# 3       abandoned     40.000000       15        6      9  17685   3837.0
# 4      abandoning     14.285714        7        1      6  17686   3837.0
# 5           abate     50.000000        2        1      1  11606  19578.0
# 6        aberrant      0.000000        3        0      3  15782  54628.0
# 7            abet     50.000000        4        2      2  11899  22237.0
# 8       abilities     33.333333        3        1      2  16289    570.0
# 9         ability     71.428571        7        5      2  11840    570.0
# 10           able     40.909091       22        9     13   9605    230.0
# 11       abnormal    100.000000        2        2      0  11607   6740.0
# ...

# %%
flights = pandas.read_csv("../WordsResearch/flightdata.csv")

# %%
print(flights)
# Out:
#                    date language                                userid  level  \
# 0       10/9/2018 23:59       it  6a66ff6a-2fbb-481e-a55c-96da275a923f      1
# 1       10/9/2018 23:59       it  6a66ff6a-2fbb-481e-a55c-96da275a923f      1
# 2       10/9/2018 23:59       it  6a66ff6a-2fbb-481e-a55c-96da275a923f      1
# 3       10/9/2018 23:58       it  6a66ff6a-2fbb-481e-a55c-96da275a923f      2
# 4       10/9/2018 23:36       es  a234435c-c722-4065-bc3a-f218b0f2acd2      2
# 5       10/9/2018 23:36       es  a234435c-c722-4065-bc3a-f218b0f2acd2      1
# 6       10/9/2018 23:36       es  a234435c-c722-4065-bc3a-f218b0f2acd2      1
# 7       10/9/2018 23:35       es  a234435c-c722-4065-bc3a-f218b0f2acd2      1
# 8       10/9/2018 23:35       es  a234435c-c722-4065-bc3a-f218b0f2acd2      1
# 9       10/9/2018 23:35       es  a234435c-c722-4065-bc3a-f218b0f2acd2      2
# 10      10/9/2018 23:35       es  a234435c-c722-4065-bc3a-f218b0f2acd2      2
# ...
